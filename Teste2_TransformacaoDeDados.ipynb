# %%
import pandas as pd
import os
from zipfile import *

# %% [markdown]
# ###### Obtendo dados do site gov.br

# %%
anexo_I_Rol_de_procedimentos = pd.read_excel('https://www.gov.br/ans/pt-br/arquivos/assuntos/consumidor/o-que-seu-plano-deve-cobrir/Anexo_I_Rol_2021RN_465.2021_RN473_RN478_RN480_RN513_RN536.xlsx', sheet_name='Anexo I_Rol de Procedimentos', skiprows=3)

# %%
anexo_I_Rol_de_procedimentos.head()
# Out:
#                                           Unnamed: 0      Unnamed: 1  \
# 0                                       PROCEDIMENTO  RN (alteração)
# 1                            ACONSELHAMENTO GENÉTICO             NaN
# 2  ATENDIMENTO/ACOMPANHAMENTO EM HOSPITAL-DIA PSI...             NaN
# 3  ATENDIMENTO INTEGRAL AO RECÉM-NASCIDO (SALA DE...             NaN
# 4  ATENDIMENTO MÉDICO DO INTENSIVISTA EM UTI GERA...             NaN
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0   VIGÊNCIA         OD        AMB        HCO        HSO        REF
# 1        NaN        NaN        AMB        HCO        HSO        REF
# 2        NaN        NaN        NaN        HCO        HSO        REF
# 3        NaN        NaN        NaN        HCO        NaN        REF
# 4        NaN        NaN        NaN        HCO        HSO        REF
#
#   Unnamed: 8 Unnamed: 9                                        Unnamed: 10  \
# 0        PAC        DUT                                           SUBGRUPO
# 1        NaN        NaN  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...
# 2        NaN        109  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...
# 3        NaN        NaN  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...
# 4        NaN        NaN  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...
#
#             Unnamed: 11           Unnamed: 12
# 0                 GRUPO              CAPÍTULO
# 1  PROCEDIMENTOS GERAIS  PROCEDIMENTOS GERAIS
# 2  PROCEDIMENTOS GERAIS  PROCEDIMENTOS GERAIS
# 3  PROCEDIMENTOS GERAIS  PROCEDIMENTOS GERAIS
# 4  PROCEDIMENTOS GERAIS  PROCEDIMENTOS GERAIS

# %% [markdown]
# ###### Renomeando colunas

# %%
anexo_I_Rol_de_procedimentos.columns = anexo_I_Rol_de_procedimentos.iloc[0]

# %%
anexo_I_Rol_de_procedimentos.head()
# Out:
# 0                                       PROCEDIMENTO  RN (alteração)  \
# 0                                       PROCEDIMENTO  RN (alteração)
# 1                            ACONSELHAMENTO GENÉTICO             NaN
# 2  ATENDIMENTO/ACOMPANHAMENTO EM HOSPITAL-DIA PSI...             NaN
# 3  ATENDIMENTO INTEGRAL AO RECÉM-NASCIDO (SALA DE...             NaN
# 4  ATENDIMENTO MÉDICO DO INTENSIVISTA EM UTI GERA...             NaN
#
# 0  VIGÊNCIA   OD  AMB  HCO  HSO  REF  PAC  DUT  \
# 0  VIGÊNCIA   OD  AMB  HCO  HSO  REF  PAC  DUT
# 1       NaN  NaN  AMB  HCO  HSO  REF  NaN  NaN
# 2       NaN  NaN  NaN  HCO  HSO  REF  NaN  109
# 3       NaN  NaN  NaN  HCO  NaN  REF  NaN  NaN
# 4       NaN  NaN  NaN  HCO  HSO  REF  NaN  NaN
#
# 0                                           SUBGRUPO                 GRUPO  \
# 0                                           SUBGRUPO                 GRUPO
# 1  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 2  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 3  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 4  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
#
# 0              CAPÍTULO
# 0              CAPÍTULO
# 1  PROCEDIMENTOS GERAIS
# 2  PROCEDIMENTOS GERAIS
# 3  PROCEDIMENTOS GERAIS
# 4  PROCEDIMENTOS GERAIS

# %%
anexo_I_Rol_de_procedimentos.drop(anexo_I_Rol_de_procedimentos.index[0], inplace=True)

# %%
anexo_I_Rol_de_procedimentos
# Out:
# 0                                          PROCEDIMENTO RN (alteração)  \
# 1                               ACONSELHAMENTO GENÉTICO            NaN
# 2     ATENDIMENTO/ACOMPANHAMENTO EM HOSPITAL-DIA PSI...            NaN
# 3     ATENDIMENTO INTEGRAL AO RECÉM-NASCIDO (SALA DE...            NaN
# 4     ATENDIMENTO MÉDICO DO INTENSIVISTA EM UTI GERA...            NaN
# 5     ATENDIMENTO PEDIÁTRICO A GESTANTES (3º TRIMESTRE)            NaN
# ...                                                 ...            ...
# 3361                                         TONOMETRIA            NaN
# 3362  TRICOGRAMA PARA DERMATOLOGIA / MINERALOGRAMA P...            NaN
# 3363                               URODINÂMICA COMPLETA            NaN
# 3364                                     UROFLUXOMETRIA            NaN
# 3365                                    VISÃO SUBNORMAL            NaN
#
# 0    VIGÊNCIA   OD  AMB  HCO  HSO  REF  PAC  DUT  \
# 1         NaN  NaN  AMB  HCO  HSO  REF  NaN  NaN
# 2         NaN  NaN  NaN  HCO  HSO  REF  NaN  109
# 3         NaN  NaN  NaN  HCO  NaN  REF  NaN  NaN
# 4         NaN  NaN  NaN  HCO  HSO  REF  NaN  NaN
# 5         NaN  NaN  AMB  HCO  NaN  REF  NaN  NaN
# ...       ...  ...  ...  ...  ...  ...  ...  ...
# 3361      NaN  NaN  AMB  HCO  HSO  REF  NaN  NaN
# 3362      NaN  NaN  AMB  HCO  HSO  REF  NaN  NaN
# 3363      NaN  NaN  AMB  HCO  HSO  REF  NaN  NaN
# 3364      NaN  NaN  AMB  HCO  HSO  REF  NaN  NaN
# 3365      NaN  NaN  AMB  HCO  HSO  REF  NaN  NaN
#
# 0                                              SUBGRUPO                 GRUPO  \
# 1     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 2     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 3     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 4     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 5     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# ...                                                 ...                   ...
# 3361                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
# 3362                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
# 3363                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
# 3364                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
# 3365                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
#
# 0                                      CAPÍTULO
# 1                          PROCEDIMENTOS GERAIS
# 2                          PROCEDIMENTOS GERAIS
# 3                          PROCEDIMENTOS GERAIS
# 4                          PROCEDIMENTOS GERAIS
# 5                          PROCEDIMENTOS GERAIS
# ...                                         ...
# 3361  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
# 3362  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
# 3363  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
# 3364  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
# 3365  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
#
# [3365 rows x 13 columns]

# %% [markdown]
# ###### Bônus(renomeando colunas OD e AMB)
#
# ![image](https://user-images.githubusercontent.com/76957963/171871936-97345a7c-1e0b-4847-a120-c69b28f1a803.png)

# %%
anexo_I_Rol_de_procedimentos.rename(columns={'OD': 'Seg.Odontológico', 'AMB': 'Seg.Ambulatorial'})
# Out:
# 0                                          PROCEDIMENTO RN (alteração)  \
# 1                               ACONSELHAMENTO GENÉTICO            NaN
# 2     ATENDIMENTO/ACOMPANHAMENTO EM HOSPITAL-DIA PSI...            NaN
# 3     ATENDIMENTO INTEGRAL AO RECÉM-NASCIDO (SALA DE...            NaN
# 4     ATENDIMENTO MÉDICO DO INTENSIVISTA EM UTI GERA...            NaN
# 5     ATENDIMENTO PEDIÁTRICO A GESTANTES (3º TRIMESTRE)            NaN
# ...                                                 ...            ...
# 3361                                         TONOMETRIA            NaN
# 3362  TRICOGRAMA PARA DERMATOLOGIA / MINERALOGRAMA P...            NaN
# 3363                               URODINÂMICA COMPLETA            NaN
# 3364                                     UROFLUXOMETRIA            NaN
# 3365                                    VISÃO SUBNORMAL            NaN
#
# 0    VIGÊNCIA Seg.Odontológico Seg.Ambulatorial  HCO  HSO  REF  PAC  DUT  \
# 1         NaN              NaN              AMB  HCO  HSO  REF  NaN  NaN
# 2         NaN              NaN              NaN  HCO  HSO  REF  NaN  109
# 3         NaN              NaN              NaN  HCO  NaN  REF  NaN  NaN
# 4         NaN              NaN              NaN  HCO  HSO  REF  NaN  NaN
# 5         NaN              NaN              AMB  HCO  NaN  REF  NaN  NaN
# ...       ...              ...              ...  ...  ...  ...  ...  ...
# 3361      NaN              NaN              AMB  HCO  HSO  REF  NaN  NaN
# 3362      NaN              NaN              AMB  HCO  HSO  REF  NaN  NaN
# 3363      NaN              NaN              AMB  HCO  HSO  REF  NaN  NaN
# 3364      NaN              NaN              AMB  HCO  HSO  REF  NaN  NaN
# 3365      NaN              NaN              AMB  HCO  HSO  REF  NaN  NaN
#
# 0                                              SUBGRUPO                 GRUPO  \
# 1     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 2     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 3     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 4     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 5     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# ...                                                 ...                   ...
# 3361                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
# 3362                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
# 3363                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
# 3364                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
# 3365                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
#
# 0                                      CAPÍTULO
# 1                          PROCEDIMENTOS GERAIS
# 2                          PROCEDIMENTOS GERAIS
# 3                          PROCEDIMENTOS GERAIS
# 4                          PROCEDIMENTOS GERAIS
# 5                          PROCEDIMENTOS GERAIS
# ...                                         ...
# 3361  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
# 3362  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
# 3363  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
# 3364  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
# 3365  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
#
# [3365 rows x 13 columns]

# %% [markdown]
# ###### Obtendo o sumario de normas

# %%
sumario_de_normas = pd.read_excel('https://www.gov.br/ans/pt-br/arquivos/assuntos/consumidor/o-que-seu-plano-deve-cobrir/Anexo_I_Rol_2021RN_465.2021_RN473_RN478_RN480_RN513_RN536.xlsx', sheet_name='Sumário de Normas')

# %%
sumario_de_normas.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 6                                 Unnamed: 7  Unnamed: 8  \
# 0         NaN                                        NaN         NaN
# 1         NaN  ROL DE PROCEDIMENTOS \nE EVENTOS EM SAÚDE         NaN
# 2         NaN                                        NaN         NaN
# 3         NaN                                        NaN         NaN
# 4         NaN                                        NaN         NaN
#
#                                           Unnamed: 9  \
# 0                                                NaN
# 1                                                NaN
# 2  (RN 465/2021, vigente a partir de 01/04/2021\n...
# 3                                                NaN
# 4                                                NaN
#
#                                       Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0                                             NaN          NaN          NaN
# 1                                             NaN          NaN          NaN
# 2                                             NaN          NaN          NaN
# 3                                             NaN          NaN          NaN
# 4  RN nº 473/2021, vigente a partir de 08/11/2021          NaN          NaN
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ###### Realizando o tratamento de dados e obtendos as colunas e linhas necessárias da folha do sumário de normas

# %%
sumario_de_normas = pd.read_excel('https://www.gov.br/ans/pt-br/arquivos/assuntos/consumidor/o-que-seu-plano-deve-cobrir/Anexo_I_Rol_2021RN_465.2021_RN473_RN478_RN480_RN513_RN536.xlsx', sheet_name='Sumário de Normas', usecols=[7,9,10], skiprows=1)

# %%
sumario_de_normas
# Out:
#                                   Unnamed: 7  \
# 0  ROL DE PROCEDIMENTOS \nE EVENTOS EM SAÚDE
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
#
#                                           Unnamed: 9  \
# 0                                                NaN
# 1  (RN 465/2021, vigente a partir de 01/04/2021\n...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#                                       Unnamed: 10
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3  RN nº 473/2021, vigente a partir de 08/11/2021
# 4  RN nº 478/2022, vigente a partir de 20/01/2022
# 5  RN nº 480/2022, vigente a partir de 14/02/2022
# 6  RN nº 536/2022, vigente a partir de 06/05/2022

# %% [markdown]
# ###### Salvando os dados em um arquivo csv

# %%
anexo_I_Rol_de_procedimentos.to_csv('Rol_de_procedimentos.csv')

# %%
pd.read_csv('Rol_de_procedimentos.csv')
# Out:
#       Unnamed: 0                                       PROCEDIMENTO  \
# 0              1                            ACONSELHAMENTO GENÉTICO
# 1              2  ATENDIMENTO/ACOMPANHAMENTO EM HOSPITAL-DIA PSI...
# 2              3  ATENDIMENTO INTEGRAL AO RECÉM-NASCIDO (SALA DE...
# 3              4  ATENDIMENTO MÉDICO DO INTENSIVISTA EM UTI GERA...
# 4              5  ATENDIMENTO PEDIÁTRICO A GESTANTES (3º TRIMESTRE)
# ...          ...                                                ...
# 3360        3361                                         TONOMETRIA
# 3361        3362  TRICOGRAMA PARA DERMATOLOGIA / MINERALOGRAMA P...
# 3362        3363                               URODINÂMICA COMPLETA
# 3363        3364                                     UROFLUXOMETRIA
# 3364        3365                                    VISÃO SUBNORMAL
#
#      RN (alteração) VIGÊNCIA   OD  AMB  HCO  HSO  REF  PAC    DUT  \
# 0               NaN      NaN  NaN  AMB  HCO  HSO  REF  NaN    NaN
# 1               NaN      NaN  NaN  NaN  HCO  HSO  REF  NaN  109.0
# 2               NaN      NaN  NaN  NaN  HCO  NaN  REF  NaN    NaN
# 3               NaN      NaN  NaN  NaN  HCO  HSO  REF  NaN    NaN
# 4               NaN      NaN  NaN  AMB  HCO  NaN  REF  NaN    NaN
# ...             ...      ...  ...  ...  ...  ...  ...  ...    ...
# 3360            NaN      NaN  NaN  AMB  HCO  HSO  REF  NaN    NaN
# 3361            NaN      NaN  NaN  AMB  HCO  HSO  REF  NaN    NaN
# 3362            NaN      NaN  NaN  AMB  HCO  HSO  REF  NaN    NaN
# 3363            NaN      NaN  NaN  AMB  HCO  HSO  REF  NaN    NaN
# 3364            NaN      NaN  NaN  AMB  HCO  HSO  REF  NaN    NaN
#
#                                                SUBGRUPO                 GRUPO  \
# 0     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 1     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 2     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 3     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 4     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# ...                                                 ...                   ...
# 3360                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
# 3361                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
# 3362                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
# 3363                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
# 3364                                      PROCEDIMENTOS    EXAMES ESPECÍFICOS
#
#                                        CAPÍTULO
# 0                          PROCEDIMENTOS GERAIS
# 1                          PROCEDIMENTOS GERAIS
# 2                          PROCEDIMENTOS GERAIS
# 3                          PROCEDIMENTOS GERAIS
# 4                          PROCEDIMENTOS GERAIS
# ...                                         ...
# 3360  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
# 3361  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
# 3362  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
# 3363  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
# 3364  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS
#
# [3365 rows x 14 columns]

# %% [markdown]
# ###### Zipando o arquivo salvo

# %%
with ZipFile('Teste_{vinicius_gonzaga}.zip', 'w') as file_zip:
    file_zip.write('Rol_de_procedimentos.csv')
